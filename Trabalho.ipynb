# %%
import pandas as pd

dados = {'Nome': ['Alice Monteiro', 'Bruno Oliveira', 'Camila Santos', 'Daniel Carvalho', 'Eduardo Almeida', 'Fernanda Costa', 'Gabriel Martins', 'Helena Rocha', 'Igor Ribeiro', 'Júlia Fernandes', 'Leonardo Lima', 'Mariana Azevedo', 'Nicolas Pereira', 'Olivia Farias', 'Paulo Barros', 'Rafaela Nunes', 'Thiago Mendes', 'Vanessa Rodrigues', 'William Batista', 'Yasmin Moraes'],
         'Nota 1': [7.5, 6.0, 9.0, 4.5, 8.0, 9.5, 5.0, 10.0, 7.2, 8.3, 6.8, 9.9, 4.0, 7.7, 6.5, 8.8, 5.5, 10.0, 6.0, 8.5],
         'Nota 2': [8.0, 5.5, 8.7, 6.0, 7.5, 9.8, 6.5, 9.5, 6.8, 9.0, 5.9, 9.7, 5.2, 8.3, 7.2, 9.1, 6.4, 9.6, 5.7, 9.0]
         }

df = pd.DataFrame(dados)
df['Média'] = (df['Nota 1'] + df['Nota 2']) / 2
df["Situação"] = df.apply(
    lambda row: "Aprovado" if row["Média"] >= 6 else "Reprovado",
    axis=1)


display(df)

caminho = r'Alunos.xlsx'
df.to_excel(caminho, index=False, engine='openpyxl')  
print(f"DataFrame salvo com sucesso em: {caminho}")
# Out:
#                  Nome  Nota 1  Nota 2  Média   Situação
# 0      Alice Monteiro     7.5     8.0   7.75   Aprovado
# 1      Bruno Oliveira     6.0     5.5   5.75  Reprovado
# 2       Camila Santos     9.0     8.7   8.85   Aprovado
# 3     Daniel Carvalho     4.5     6.0   5.25  Reprovado
# 4     Eduardo Almeida     8.0     7.5   7.75   Aprovado
# 5      Fernanda Costa     9.5     9.8   9.65   Aprovado
# 6     Gabriel Martins     5.0     6.5   5.75  Reprovado
# 7        Helena Rocha    10.0     9.5   9.75   Aprovado
# 8        Igor Ribeiro     7.2     6.8   7.00   Aprovado
# 9     Júlia Fernandes     8.3     9.0   8.65   Aprovado
# 10      Leonardo Lima     6.8     5.9   6.35   Aprovado
# 11    Mariana Azevedo     9.9     9.7   9.80   Aprovado
# 12    Nicolas Pereira     4.0     5.2   4.60  Reprovado
# 13      Olivia Farias     7.7     8.3   8.00   Aprovado
# 14       Paulo Barros     6.5     7.2   6.85   Aprovado
# 15      Rafaela Nunes     8.8     9.1   8.95   Aprovado
# ...

# %%
# Caso queira ver se realmente foi salvo em arquivo Excel

dados = pd.read_excel(r'Alunos.xlsx')

display(dados)
# Out:
#                  Nome  Nota 1  Nota 2  Média   Situação
# 0      Alice Monteiro     7.5     8.0   7.75   Aprovado
# 1      Bruno Oliveira     6.0     5.5   5.75  Reprovado
# 2       Camila Santos     9.0     8.7   8.85   Aprovado
# 3     Daniel Carvalho     4.5     6.0   5.25  Reprovado
# 4     Eduardo Almeida     8.0     7.5   7.75   Aprovado
# 5      Fernanda Costa     9.5     9.8   9.65   Aprovado
# 6     Gabriel Martins     5.0     6.5   5.75  Reprovado
# 7        Helena Rocha    10.0     9.5   9.75   Aprovado
# 8        Igor Ribeiro     7.2     6.8   7.00   Aprovado
# 9     Júlia Fernandes     8.3     9.0   8.65   Aprovado
# 10      Leonardo Lima     6.8     5.9   6.35   Aprovado
# 11    Mariana Azevedo     9.9     9.7   9.80   Aprovado
# 12    Nicolas Pereira     4.0     5.2   4.60  Reprovado
# 13      Olivia Farias     7.7     8.3   8.00   Aprovado
# 14       Paulo Barros     6.5     7.2   6.85   Aprovado
# 15      Rafaela Nunes     8.8     9.1   8.95   Aprovado
# ...
